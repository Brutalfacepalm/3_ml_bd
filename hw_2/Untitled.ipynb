# %%
from pyhive import hive
import pandas as pd

# %%
conn = hive.Connection(host='localhost', port=10000)

# %%
dataframe = pd.read_sql("SELECT * FROM hue__tmp_artists_hw_2", conn)

# %%
dataframe
# Out:
#                    hue__tmp_artists_hw_2.mbid hue__tmp_artists_hw_2.artist_mb  \
# 0        cc197bad-dc9c-440d-a5b5-d52ba2e14234                        Coldplay
# 1        a74b1b7f-71a5-4011-9441-d0b5e4122711                       Radiohead
# 2        8bfac288-ccc5-448d-9573-c33ea2aa5c30           Red Hot Chili Peppers
# 3        73e5e69d-3554-40d8-8516-00cb38737a1c                         Rihanna
# 4        b95ce3ff-3d05-4e87-9e01-c97b66af13d4                          Eminem
# ...                                       ...                             ...
# 1466077  1eab523e-98ff-4083-aa34-8922740bc696                             정은지
# 1466078  a18f0527-907e-42b0-8268-504966274581                             남태현
# 1466079  20a57e37-24b5-4301-855b-35076580fb88                             헤일로
# 1466080  83891a4d-1bf4-4abe-a483-5b3d9d614efa                             서현진
# 1466081  3d05dd13-f524-4e80-91aa-24094e8b5928                             김희철
#
# ...
